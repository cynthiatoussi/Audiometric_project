# %%
from pathlib import Path

project_path = Path.cwd()

from kedro.framework.session import KedroSession

session = KedroSession.create()
context = session.load_context()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │   4                                                                                              │
# │   5 from kedro.framework.session import KedroSession                                             │
# │   6                                                                                              │
# │ ❱ 7 session = KedroSession.create()                                                              │
# │   8 context = session.load_context()                                                             │
# │   9                                                                                              │
# │                                                                                                  │
# │ c:\Users\VICTUS\anaconda3\Lib\site-packages\kedro\framework\session\session.py:158 in create     │
# │                                                                                                  │
# │ c:\Users\VICTUS\anaconda3\Lib\site-packages\kedro\framework\project\__init__.py:335 in           │
# │ validate_settings                                                                                │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Package name not found. Make sure you have configured the project using 'bootstrap_project'. This
# should happen automatically if you are using Kedro command line interface.

# %%
import pandas as pd

X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])

print(y["gain_exam_4000_Hz"].describe())
# Out:
# count    5338.000000
# mean       11.446431
# std         8.860156
# min       -98.000000
# 25%         7.000000
# 50%        11.000000
# 75%        15.000000
# max       111.330000
# Name: gain_exam_4000_Hz, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    x=X["before_exam_4000_Hz"],
    y=y["gain_exam_4000_Hz"]
)

plt.title("Before vs Gain à 4000 Hz")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
model = context.catalog.load("trained_model")

import pandas as pd

importance_df = pd.DataFrame({
    "feature": X.columns,
    "importance": model.feature_importances_
}).sort_values(by="importance", ascending=False)

importance_df
# Out:
# [03/02/26 12:53:34] WARNING  c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\kedro\framew ]8;id=730886;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\warnings.py\warnings.py]8;;\:]8;id=814561;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\warnings.py#109\109]8;;\
#                              ork\context\context.py:219: UserWarning: Parameters not found in your
#                              Kedro project config.
#                              No files of YAML or JSON format found in C:\Users\VICTUS\OneDrive -
#                              Reseau-GES\Documents\Bureau\ESGI\M2_IABD\industrialisation des
#                              modèles\gain-project\conf\base or C:\Users\VICTUS\OneDrive -
#                              Reseau-GES\Documents\Bureau\ESGI\M2_IABD\industrialisation des
#                              modèles\gain-project\conf\local matching the glob pattern(s):
#                              ['parameters*', 'parameters*/**', '**/parameters*']
#                                warn(f"Parameters not found in your Kedro project config.\n{exc!s}")
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=155985;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=794232;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\kedro_telemetry\plugin.py#242\242]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/about/telemetry/
#                     INFO     Loading data from trained_model (PickleDataset)...                ]8;id=108846;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=742992;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
#                     WARNING  c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\sklearn\base ]8;id=177319;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\warnings.py\warnings.py]8;;\:]8;id=614870;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\warnings.py#109\109]8;;\
#                              .py:442: InconsistentVersionWarning: Trying to unpickle estimator
#                              DecisionTreeRegressor from version 1.5.1 when using version 1.7.2.
#                              This might lead to breaking code or invalid results. Use at your own
#                              risk. For more info please refer to:
#                              https://scikit-learn.org/stable/model_persistence.html#security-mainta
#                              inability-limitations
#                                warnings.warn(
# [03/02/26 12:53:35] WARNING  c:\Users\VICTUS\anaconda3\envs\gain_env\lib\site-packages\sklearn\base ]8;id=335025;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\warnings.py\warnings.py]8;;\:]8;id=713132;file://c:\Users\VICTUS\anaconda3\envs\gain_env\lib\warnings.py#109\109]8;;\
#                              .py:442: InconsistentVersionWarning: Trying to unpickle estimator
#                              RandomForestRegressor from version 1.5.1 when using version 1.7.2.
#                              This might lead to breaking code or invalid results. Use at your own
#                              risk. For more info please refer to:
#                              https://scikit-learn.org/stable/model_persistence.html#security-mainta
#                              inability-limitations
#                                warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                feature  importance
# 0   before_exam_125_Hz    0.263056
# 1   before_exam_250_Hz    0.147773
# 5  before_exam_4000_Hz    0.142441
# 6  before_exam_8000_Hz    0.121442
# 2   before_exam_500_Hz    0.116442
# 4  before_exam_2000_Hz    0.114490
# 3  before_exam_1000_Hz    0.094357
